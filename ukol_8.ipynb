# %% [markdown]
# ÚKOL_8:
# Stáhni si dataset, který obsahuje seznam zvířat k adopci v ZOO Praha. Zdroj dat je Národní katalog otevřených dat.
#     Data si načti pomocí metody pandas.read_csv(). Pozor, nastav oddělovač na znak středníku. Využij parametr sep.
#     Seznam se s daty. Kolik má tabulka řádek a sloupců? Jak se sloupce jmenují?
#     Které zvíře se nachází na záznamu s indexem 34? Vypiš název tohoto zvířete v češtině a v angličtině.

# %%
import pandas

# %%
adopce = pandas.read_csv("adopce-zvirat.txt",sep=";")
adopce
# Out:
#        id             nazev_cz                     nazev_en       trida_cz  \
# 0       7          Šváb syčivý  Madagascar giant cockroach      Bezobratlí
# 1       8  Pakobylka okřídlená     Pink-winged stick insect     Bezobratlí
# 2      16                Tayra                        Tayra          Savci
# 3      35        Kajmanka supí    Alligator snapping turtle          Plazi
# 4      37      Želva žlutočelá       Indochinese box turtle          Plazi
# ..    ...                  ...                          ...            ...
# 508  1417  Rosnice šalamounská                               Obojživelníci
# 509  1418       Létavka obecná                               Obojživelníci
# 510  1419          Bažant paví                                       Ptáci
# 511  1420  Sojkovec rezavouchý                                       Ptáci
# 512  1421   Kachnice kaštanová                                       Ptáci
#
#      cena  k_prohlidce
# 0    1000            1
# 1    1000            1
# 2    5000            1
# 3    2000            1
# 4    1000            1
# ..    ...          ...
# 508  1000            1
# 509  1000            1
# 510  1000            1
# 511  1000            1
# 512  1000            1
#
# [513 rows x 6 columns]

# %%
adopce.columns #názvy sloupců
# Out:
# Index(['id', 'nazev_cz', 'nazev_en', 'trida_cz', 'cena', 'k_prohlidce'], dtype='object')

# %%
adopce.shape #vzhled tabulky...6 sloupců a 513 řádků
# Out:
# (513, 6)

# %%
adopce.iloc[34][["nazev_cz","nazev_en"]]
# Out:
# nazev_cz     Ibis bílý
# nazev_en    White ibis
# Name: 34, dtype: object

# %% [markdown]
# NEPOVINNÝ BONUS:
# Využij metody sort_values() (a libovolných dalších metod), ke zjištění následujících informací:
#     Adopce kterých zvířat je nejdražší?
#     Které zvíře je alfabeticky poslední v češtině? Které v angličtině?
#     Bonus můžeš doplnit o nějaké vlastní pozorování.

# %%
serazeni = adopce.sort_values(["cena"],ascending=False)#nastavení ascending=False řadí od nejvyšší hodnoty
serazeni[:8]
# Out:
#        id                                   nazev_cz                nazev_en  \
# 114   335                            Tygr sumaterský          Sumatran tiger
# 113   334                            Tygr ussurijský          Siberian tiger
# 272   897                              Tygr malajský           Malayan tiger
# 129   385                          Hroch obojživelný            Hippopotamus
# 128   381                               Slon indický          Asian elephant
# 135   396  Žirafa severní núbijská (= Rothschildova)  Rothschild's giraffe
# 330  1101                             Gaviál indický          Indian gharial
# 101   297                       Orangutan sumaterský     Sumatran orang-utan
#
#     trida_cz   cena  k_prohlidce
# 114    Savci  50000            1
# 113    Savci  50000            1
# 272    Savci  50000            1
# 129    Savci  50000            1
# 128    Savci  50000            1
# 135    Savci  50000            1
# 330    Plazi  30000            1
# 101    Savci  30000            1

# %%
adopce.sort_values(["nazev_cz"],ascending=False)
# Out:
#        id                                   nazev_cz                 nazev_en  \
# 371  1190                                Žluva hajní   Eurasian golden oriole
# 321  1069                                Žluna větší       Greater yellownape
# 135   396  Žirafa severní núbijská (= Rothschildova)   Rothschild's giraffe
# 4      37                            Želva žlutočelá   Indochinese box turtle
# 211   673                              Želva černavá  Giant Asian pond turtle
# ..    ...                                        ...                      ...
# 391  1233                             Agamka písečná        Toad-headed agama
# 383  1215                         Agama turkestánská     Turkestan rock agama
# 382  1214                               Agama stepní             Steppe agama
# 138   402                                       Adax                    Addax
# 194   621                             Achatina žravá      Giant African snail
#
#        trida_cz   cena  k_prohlidce
# 371       Ptáci   1000            1
# 321       Ptáci   1500            1
# 135       Savci  50000            1
# 4         Plazi   1000            1
# 211       Plazi   2000            1
# ..          ...    ...          ...
# 391       Plazi   1500            1
# 383       Plazi   1500            1
# 382       Plazi   1000            1
# 138       Savci   5000            1
# 194  Bezobratlí   1000            1
#
# [513 rows x 6 columns]

# %%
adopce.sort_values(["nazev_en"],ascending=False)
# Out:
#        id             nazev_cz                 nazev_en trida_cz  cena  \
# 161   491  Frankolín žlutokrký  Yellow-necked francolin    Ptáci  1000
# 455  1347    Vlhovec žlutokápý  Yellow-hooded blackbird    Ptáci  1000
# 341  1140      Majna žlutolící       Yellow-faced mynah    Ptáci  2000
# 230   745        Nesyt africký      Yellow-billed stork    Ptáci  2500
# 196   628       Mangusta liščí          Yellow mongoose    Savci  5000
# ..    ...                  ...                      ...      ...   ...
# 303  1010        Zvonek zelený                             Ptáci  1000
# 491  1396       Kolpík africký                             Ptáci  3000
# 249   800          Husa domácí                             Ptáci  1500
# 483  1385  Tkalčík červenozobý                             Ptáci  1000
# 512  1421   Kachnice kaštanová                             Ptáci  1000
#
#      k_prohlidce
# 161            1
# 455            0
# 341            1
# 230            0
# 196            1
# ..           ...
# 303            1
# 491            1
# 249            1
# 483            1
# 512            1
#
# [513 rows x 6 columns]

# %%
birds = adopce[adopce["trida_cz"].isin(["Ptáci"])] #zajímalo mě, jaké druhy ptáků jsou nejdražší
birds.sort_values(["cena"],ascending=False)
# Out:
#        id                                  nazev_cz               nazev_en  \
# 25     87                              Pelikán bílý  Eastern white pelican
# 26     88                          Pelikán kadeřavý      Dalmatian pelican
# 413  1278                        Pelikán skvrnozobý    Spot-billed pelican
# 22     84                           Kasuár přílbový     Southern cassowary
# 271   895                        Člunozobec africký               Shoebill
# ..    ...                                       ...                    ...
# 276   910  Papoušek vlnkovaný (= andulka vlnkovaná)             Budgerigar
# 277   911                          Papoušek zpěvavý      Red-rumped parrot
# 279   915                            Šafránka velká          Saffron finch
# 280   917                              Holub skalní            Rock pigeon
# 512  1421                        Kachnice kaštanová
#
#     trida_cz  cena  k_prohlidce
# 25     Ptáci  8000            1
# 26     Ptáci  8000            1
# 413    Ptáci  8000            0
# 22     Ptáci  8000            1
# 271    Ptáci  6000            1
# ..       ...   ...          ...
# 276    Ptáci  1000            0
# 277    Ptáci  1000            1
# 279    Ptáci  1000            1
# 280    Ptáci  1000            1
# 512    Ptáci  1000            1
#
# [237 rows x 6 columns]
